# %% [markdown]
# # Deep Learning -  Convolutional Neural Network

# %% [markdown]
# ### Importing libraries

# %%
import numpy as np
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image

# %% [markdown]
# ## Part 1 - Data Preprocessing

# %% [markdown]
# ### Preprocessing the training set

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

training_set = train_datagen.flow_from_directory(
    'dataset/training_set',
    target_size=(64, 64),
    batch_size=32,
    class_mode='binary'
)
# Out:
# Found 8000 images belonging to 2 classes.

# %% [markdown]
# ### Preprocessing the test set

# %%
test_datagen = ImageDataGenerator(rescale=1./255)

test_set = test_datagen.flow_from_directory(
    'dataset/test_set',
    target_size=(64, 64),
    batch_size=32,
    class_mode='binary'
)
# Out:
# Found 2000 images belonging to 2 classes.

# %% [markdown]
# ## Part 2 - Building the CNN

# %% [markdown]
# ### Initializing the CNN

# %%
cnn = tf.keras.models.Sequential()

# %% [markdown]
# ### Step 1 - Convolution

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=[64, 64, 3]))

# %% [markdown]
# ### Step 2 - Pooling

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# ### Adding a second convolutional layer

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# ### Step 3 - Flattening

# %%
cnn.add(tf.keras.layers.Flatten())

# %% [markdown]
# ### Step 4 - Full connection

# %%
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))

# %% [markdown]
# ### Step 5 - Output layer

# %%
cnn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %% [markdown]
# ## Part 3 - Training the CNN

# %% [markdown]
# ### Compiling the CNN

# %%
cnn.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Training the CNN on the training set and evaluating it on the test set

# %%
cnn.fit(x=training_set, validation_data=test_set, epochs=25)
# Out:
# Epoch 1/25
# 250/250 [==============================] - 281s 1s/step - loss: 0.6868 - accuracy: 0.5577 - val_loss: 0.6326 - val_accuracy: 0.6695
# Epoch 2/25
# 250/250 [==============================] - 79s 315ms/step - loss: 0.6134 - accuracy: 0.6654 - val_loss: 0.6325 - val_accuracy: 0.6460
# Epoch 3/25
# 250/250 [==============================] - 71s 283ms/step - loss: 0.5581 - accuracy: 0.7112 - val_loss: 0.5157 - val_accuracy: 0.7560
# Epoch 4/25
# 250/250 [==============================] - 75s 298ms/step - loss: 0.5184 - accuracy: 0.7448 - val_loss: 0.5084 - val_accuracy: 0.7480
# Epoch 5/25
# 250/250 [==============================] - 75s 300ms/step - loss: 0.4967 - accuracy: 0.7537 - val_loss: 0.5103 - val_accuracy: 0.7595
# Epoch 6/25
# 250/250 [==============================] - 82s 329ms/step - loss: 0.4602 - accuracy: 0.7725 - val_loss: 0.4897 - val_accuracy: 0.7720
# Epoch 7/25
# 250/250 [==============================] - 81s 324ms/step - loss: 0.4585 - accuracy: 0.7859 - val_loss: 0.4848 - val_accuracy: 0.7830
# Epoch 8/25
# 250/250 [==============================] - 82s 329ms/step - loss: 0.4316 - accuracy: 0.7961 - val_loss: 0.4825 - val_accuracy: 0.7825
# Epoch 9/25
# 250/250 [==============================] - 85s 339ms/step - loss: 0.4349 - accuracy: 0.7942 - val_loss: 0.4836 - val_accuracy: 0.7730
# Epoch 10/25
# 250/250 [==============================] - 81s 326ms/step - loss: 0.4133 - accuracy: 0.8109 - val_loss: 0.4708 - val_accuracy: 0.7805
# Epoch 11/25
# 250/250 [==============================] - 83s 331ms/step - loss: 0.4016 - accuracy: 0.8152 - val_loss: 0.4628 - val_accuracy: 0.7865
# Epoch 12/25
# 250/250 [==============================] - 83s 333ms/step - loss: 0.3937 - accuracy: 0.8205 - val_loss: 0.4578 - val_accuracy: 0.7885
# Epoch 13/25
# 250/250 [==============================] - 82s 329ms/step - loss: 0.3871 - accuracy: 0.8245 - val_loss: 0.4607 - val_accuracy: 0.7855
# Epoch 14/25
# 250/250 [==============================] - 191s 766ms/step - loss: 0.3725 - accuracy: 0.8315 - val_loss: 0.4947 - val_accuracy: 0.7740
# Epoch 15/25
# 250/250 [==============================] - 131s 525ms/step - loss: 0.3479 - accuracy: 0.8449 - val_loss: 0.4683 - val_accuracy: 0.7995
# Epoch 16/25
# 250/250 [==============================] - 164s 658ms/step - loss: 0.3385 - accuracy: 0.8500 - val_loss: 0.4651 - val_accuracy: 0.7980
# Epoch 17/25
# 250/250 [==============================] - 212s 847ms/step - loss: 0.3439 - accuracy: 0.8512 - val_loss: 0.4693 - val_accuracy: 0.8040
# Epoch 18/25
# 250/250 [==============================] - 121s 483ms/step - loss: 0.3103 - accuracy: 0.8593 - val_loss: 0.5273 - val_accuracy: 0.7845
# Epoch 19/25
# 250/250 [==============================] - 83s 333ms/step - loss: 0.2960 - accuracy: 0.8693 - val_loss: 0.4716 - val_accuracy: 0.8065
# Epoch 20/25
# 250/250 [==============================] - 81s 326ms/step - loss: 0.2900 - accuracy: 0.8763 - val_loss: 0.4745 - val_accuracy: 0.8010
# Epoch 21/25
# 250/250 [==============================] - 81s 323ms/step - loss: 0.2819 - accuracy: 0.8796 - val_loss: 0.4732 - val_accuracy: 0.8100
# Epoch 22/25
# 250/250 [==============================] - 81s 325ms/step - loss: 0.2713 - accuracy: 0.8880 - val_loss: 0.4917 - val_accuracy: 0.8050
# Epoch 23/25
# 250/250 [==============================] - 82s 327ms/step - loss: 0.2666 - accuracy: 0.8897 - val_loss: 0.4996 - val_accuracy: 0.8090
# Epoch 24/25
# 250/250 [==============================] - 83s 332ms/step - loss: 0.2540 - accuracy: 0.8904 - val_loss: 0.4955 - val_accuracy: 0.8055
# Epoch 25/25
# 250/250 [==============================] - 193s 774ms/step - loss: 0.2312 - accuracy: 0.9019 - val_loss: 0.5470 - val_accuracy: 0.7925

# %% [markdown]
# ## Part 4 - Making a single prediction

# %%
test_image = image.load_img(path='dataset/single_prediction/cat_or_dog_1.jpg', target_size=(64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis=0)
result = cnn.predict(x=test_image)
training_set.class_indices
if result[0][0] == 1:
    prediction = 'dog'
else:
    prediction = 'cat'
print(prediction)
# Out:
# dog

# %%
test_image = image.load_img(path='dataset/single_prediction/cat_or_dog_2.jpg', target_size=(64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis=0)
result = cnn.predict(x=test_image)
training_set.class_indices
if result[0][0] == 1:
    prediction = 'dog'
else:
    prediction = 'cat'
print(prediction)
# Out:
# dog

# %%
test_image = image.load_img(path='dataset/single_prediction/cat_or_dog_3.jpg', target_size=(64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis=0)
result = cnn.predict(x=test_image)
training_set.class_indices
if result[0][0] == 1:
    prediction = 'dog'
else:
    prediction = 'cat'
print(prediction)
# Out:
# dog

# %%
test_image = image.load_img(path='dataset/single_prediction/cat_or_dog_4.jpg', target_size=(64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis=0)
result = cnn.predict(x=test_image)
training_set.class_indices
if result[0][0] == 1:
    prediction = 'dog'
else:
    prediction = 'cat'
print(prediction)
# Out:
# dog
